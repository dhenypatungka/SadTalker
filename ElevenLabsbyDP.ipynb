# %% [markdown]
# <a href="https://colab.research.google.com/github/dhenypatungka/SadTalker/blob/main/ElevenLabsbyDP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title ## **1. Install ElevenLabs**
# !pip install elevenlabs -U

# %%
from elevenlabs import generate, play
#Pilihan voice: Bella, Antoni, Adam, Arnold, Callum, Charlie, Charlotte, Clyde, Daniel, Dave, Domi, Dorothy, Michael, Liam, Jessie, Elli, Emily, Ethan, Gigi, Giovanni, Thomas, Sam, Serena, Mimi, Glinda, Grace

audio = generate (
    text= "Hi nama saya donald trump, presiden Amerika yang paling kontrofersi.",
    voice= "Antoni" ,
    model= "eleven_multilingual_v2",
)

play(audio, notebook=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
